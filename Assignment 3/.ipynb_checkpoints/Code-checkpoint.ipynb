# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import math
import json
import sys
import time
import json
import re
import csv
from tqdm.notebook import tqdm
from itertools import combinations
from PorterStemmer import *
ps = PorterStemmer()

# %%
delim = '''[ ',<>(){}.:;"`\n]'''
def getTokensFromText(text):
    words = re.split(delim, text)
    res = []
    for w in words:
        if(len(w) > 2):
            temp = ps.stem(w.lower(), 0, len(w)-1)
            temp = w.lower()
            if not re.search('[0-9]+', temp):
                res.append(temp)
    return res

# %%
data_dir = r"C:\Files\a3data\20news-bydate-test"

# %%
def process_data():
    data = {}
    
    for topic in tqdm(os.listdir(data_dir)):
        topic_path = os.path.join(data_dir,topic)
        for uid in os.listdir(topic_path):
            full_path = os.path.join(topic_path,uid)
            with open(full_path) as filedata:
                filedata = filedata.read()
                tokens = getTokensFromText(filedata)
                data[uid] = tokens
        break
    return data
data = process_data()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))

# %%
def get_idf_dict_new():
    idf_dict = {}
    for uid in tqdm(data):
        tokens = data[uid]
        for token in tokens:
            if token not in idf_dict:
                idf_dict[token] = 1
            else:
                idf_dict[token] += 1
    return idf_dict
idf_dict = get_idf_dict_new()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=319.0), HTML(value='')))

# %%
def create_vocab_dict(idf_dict):
    vocab = {}
    for i, word in enumerate(idf_dict.keys()):
        vocab[word] = i
    return vocab

# %%
N = len(data)
vocab = create_vocab_dict(idf_dict)

# %%
def get_idf(term):
    return math.log(1+N/idf_dict[term], 2)

# %%
def get_tf_dict(docid):
    tf_dict = {}
    tokens = data[docid]
    for token in tokens:
        if token not in tf_dict:
            tf_dict[token] = 1
        else:
            tf_dict[token] += 1
    return tf_dict

# %%
def getDocVector(docid):
    tf_dict = get_tf_dict(docid)
    vec = np.zeros(len(vocab))
    for word, tf in tf_dict.items():
        if word in vocab:
            pos = vocab[word]
            normtf = 1 + math.log(tf, 2)
            normidf = get_idf(word)
            tfidf = normtf * normidf
            vec[pos] = tfidf
    return vec

# %%
def precomputeDocVecs():
    vecs = {}
    alluids = list(data.keys())
    for uid in tqdm(alluids):
        vec = getDocVector(uid)
        vecs[uid] = vec
    return vecs
uid_to_vec = precomputeDocVecs()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=319.0), HTML(value='')))

# %%
def getCosineSim(uid1, uid2):
    docVec1 = uid_to_vec[uid1]
    docVec2 = uid_to_vec[uid2]
    if np.linalg.norm(docVec1) == 0 or np.linalg.norm(docVec2) == 0:
        return 0.0
    return np.dot(docVec1, docVec2)/(np.linalg.norm(docVec1) * np.linalg.norm(docVec2))

# %%
def getJacobianSim(uid1, uid2):
    tokens1 = set(data[uid1])
    tokens2 = set(data[uid2])
    intersection = tokens1.intersection(tokens2)
    union = tokens1.union(tokens2)
    return len(intersection)/len(union)

# %%
def getWeightedEdges(similarity):
    alluids = list(data.keys())
    edges = list(combinations(alluids, 2))
    edges = edges[:20000]
    weighted_edges = []
    for e in tqdm(edges):
        v1 = e[0]
        v2 = e[1]
        if similarity == 1:
            w = getCosineSim(v1,v2)
        else:
            w = getJacobianSim(v1,v2)
        weighted_edges.append((v1,v2,w))
        weighted_edges.append((v2,v1,w))
    return weighted_edges

# %%
alluids = list(data.keys())
edges = list(combinations(alluids, 2))
len(edges)
# Out:
# 50721

# %%
weights = getWeightedEdges(2)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))

# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_nodes_from(list(data.keys()))

# %%
G.add_weighted_edges_from(weights)

# %%
pr = nx.pagerank(G, alpha=0.85)

# %%
dict(sorted(pr.items(), key=lambda item: item[1],reverse=True))
# Out:
# {'53261': 0.010227675542109883,
#  '53280': 0.009622442985388844,
#  '53322': 0.009333126862441034,
#  '53343': 0.009309251274469247,
#  '53319': 0.009236913632321556,
#  '53342': 0.009217498374517349,
#  '53350': 0.008823798580121755,
#  '53068': 0.00869421406923838,
#  '53409': 0.008685147830630686,
#  '53397': 0.008675722878272962,
#  '53316': 0.008650493387893856,
#  '53328': 0.008587084070073199,
#  '53408': 0.008520180222355235,
#  '53265': 0.008504505583868591,
#  '53346': 0.008450724042225827,
#  '53326': 0.00836562782705504,
#  '53404': 0.008352468778677485,
#  '53332': 0.008313891589754315,
#  '53313': 0.008298996571050007,
#  '53398': 0.008248389324332615,
#  '53302': 0.008238776974870757,
#  '53355': 0.008217748447912258,
#  '53320': 0.00817133689728981,
#  '53340': 0.008142533983119416,
#  '53333': 0.008134368685616207,
#  '53396': 0.008124991835212751,
#  '53338': 0.008107349253255104,
#  '53329': 0.008102167629566429,
#  '53358': 0.008050171222438233,
#  '53257': 0.008045547827847308,
#  '53260': 0.008044538585003506,
#  '53359': 0.007934923033643402,
#  '53279': 0.007886391800079922,
#  '53353': 0.007881310114899688,
#  '53293': 0.007711309647885038,
#  '53262': 0.007663081256817818,
#  '53327': 0.007601623907494578,
#  '53400': 0.007589772940398489,
#  '53405': 0.0075729484335206165,
#  '53331': 0.007544247926714253,
#  '53406': 0.007494048525178001,
#  '53294': 0.007492618803117014,
#  '53337': 0.007447899952694272,
#  '53402': 0.0074213315612549294,
#  '53344': 0.007352108180397896,
#  '53357': 0.007340471636999056,
#  '53297': 0.007318481848682597,
#  '53393': 0.007306450795714278,
#  '53399': 0.007298591051113592,
#  '53324': 0.00729336697346196,
#  '53394': 0.007279582077158163,
#  '53325': 0.007188841757248211,
#  '53364': 0.0071595846896110645,
#  '53278': 0.007144366493119069,
#  '53276': 0.007027319268155671,
#  '53349': 0.00700564061530396,
#  '53339': 0.006906549692393597,
#  '53361': 0.006901801850843266,
#  '53277': 0.006783896061171188,
#  '53403': 0.006780446914910809,
#  '53315': 0.0065751834659249445,
#  '53317': 0.006553888014587582,
#  '53365': 0.0065054052852779026,
#  '53272': 0.006390902193010427,
#  '53356': 0.0062883970098362284,
#  '53363': 0.00625020821951586,
#  '53410': 0.0058908714266354,
#  '53362': 0.005879721404775402,
#  '53335': 0.0058326175321788505,
#  '53321': 0.00571768136155989,
#  '53401': 0.005099001777261728,
#  '53424': 0.0025837587576504457,
#  '54175': 0.0025421697978940333,
#  '53669': 0.0024059286981188877,
#  '53537': 0.0022971804678144758,
#  '53425': 0.002287381999294527,
#  '53675': 0.0022339929481193913,
#  '53491': 0.0022158160706467495,
#  '53426': 0.002205689150664188,
#  '54191': 0.0021974827220413214,
#  '53635': 0.0021884232648470957,
#  '53539': 0.002187085579330649,
#  '53502': 0.0021808353092919934,
#  '53458': 0.0021798001769816008,
#  '53634': 0.0021735953565703925,
#  '54192': 0.0021630544371310603,
#  '53473': 0.0021625168873213667,
#  '53790': 0.002162334366839314,
#  '53421': 0.002155716827075567,
#  '54237': 0.0021533484100191044,
#  '53498': 0.002144549647367741,
#  '53581': 0.0021207342419602413,
#  '53677': 0.0021205993424297793,
#  '53644': 0.0021170116576490388,
#  '54193': 0.0021160458154552797,
#  '53583': 0.002112376187725921,
#  '54142': 0.0021093511401268795,
#  '53493': 0.002107731317381696,
#  '53538': 0.00210573948741896,
#  '53586': 0.0021032556324923103,
#  '54134': 0.002099300836470448,
#  '53540': 0.002097663697162866,
#  '54481': 0.00209324819634553,
#  '53791': 0.0020924172743152355,
#  '54160': 0.0020853746911861206,
#  '53605': 0.0020850003193071593,
#  '53589': 0.002084232842270034,
#  '54244': 0.0020765254527280274,
#  '53429': 0.0020732557434814695,
#  '53810': 0.0020643965410648206,
#  '54144': 0.0020639780562161005,
#  '54261': 0.0020545867903729058,
#  '54217': 0.0020511707277401036,
#  '53503': 0.002050007169462794,
#  '53414': 0.0020499136744053545,
#  '54248': 0.00204886056450563,
#  '53423': 0.0020483963289792853,
#  '53808': 0.002040575373546704,
#  '53495': 0.002036344929341718,
#  '53598': 0.0020353674386682278,
#  '53496': 0.0020339673211246206,
#  '53412': 0.0020308950838321955,
#  '53623': 0.002023874755563897,
#  '53631': 0.0020228251597533575,
#  '53487': 0.0020187099234099163,
#  '53549': 0.0020155708753596432,
#  '54250': 0.002014110969596409,
#  '54126': 0.0020090384182874154,
#  '53629': 0.0020077770364082155,
#  '53657': 0.002006510159965293,
#  '54225': 0.002005214787526318,
#  '53591': 0.0020030259074898193,
#  '53555': 0.0020027753672200626,
#  '54137': 0.0020009101687048928,
#  '53482': 0.0019997897943203396,
#  '53544': 0.00199870305486333,
#  '53472': 0.0019974078471611087,
#  '53670': 0.001996994502719905,
#  '53649': 0.0019893348067543254,
#  '53601': 0.001988078371738245,
#  '53431': 0.001983123371943068,
#  '54221': 0.0019826474578422152,
#  '54247': 0.0019807849501095893,
#  '54138': 0.0019760439087876842,
#  '53447': 0.001975991470161604,
#  '54468': 0.0019758433885025597,
#  '54183': 0.0019719460327336192,
#  '54254': 0.0019715208781175726,
#  '53609': 0.0019663669846182686,
#  '53428': 0.0019656332750677304,
#  '54127': 0.001956426677072984,
#  '53430': 0.0019538523555453734,
#  '53673': 0.0019532111281061844,
#  '54196': 0.0019518534184288269,
#  '53604': 0.001950569374812369,
#  '54245': 0.0019468126616621526,
#  '53671': 0.0019465959955620089,
#  '53411': 0.0019416381595123529,
#  '53600': 0.0019392167686937882,
#  '53642': 0.0019362331477247848,
#  '53488': 0.0019361796839571844,
#  '53416': 0.001934881448031649,
#  '53541': 0.0019313771482308323,
#  '54128': 0.0019298997629240266,
#  '53500': 0.0019259671420191467,
#  '53627': 0.001924916187260476,
#  '54189': 0.0019243360040363969,
#  '53606': 0.001924322774911008,
#  '53413': 0.001920423334214019,
#  '53504': 0.0019191320259516666,
#  '53602': 0.001917537289759427,
#  '53479': 0.0019163689332783883,
#  '54133': 0.0019148986528332668,
#  '53624': 0.0019094731246637766,
#  '53582': 0.0019032182598616723,
#  '53552': 0.0019010974234095553,
#  '54260': 0.0018942526109757235,
#  '54141': 0.0018925099360714787,
#  '54233': 0.001891468836647842,
#  '53619': 0.0018902551517041026,
#  '54231': 0.0018896414118365534,
#  '54239': 0.0018875548396384458,
#  '53664': 0.0018870539275836701,
#  '54187': 0.0018802528488462403,
#  '54238': 0.0018755603587003239,
#  '54194': 0.0018752858022524643,
#  '53575': 0.0018740204399512862,
#  '53663': 0.0018727031458316047,
#  '53420': 0.0018722980112829682,
#  '53786': 0.0018703384504417326,
#  '53588': 0.0018686621602135528,
#  '53783': 0.0018651151589905777,
#  '54220': 0.0018620825305737502,
#  '53469': 0.0018620153556724896,
#  '54135': 0.0018594761063396264,
#  '54170': 0.0018556350340385084,
#  '53563': 0.0018553137531197124,
#  '53558': 0.0018533006599285955,
#  '53454': 0.0018514863883031347,
#  '54246': 0.0018509815270188387,
#  '54224': 0.0018497178940099232,
#  '53804': 0.0018457527020961646,
#  '53630': 0.0018441208866051555,
#  '53474': 0.001841781595777392,
#  '53594': 0.0018340181795394735,
#  '54259': 0.0018255075118817003,
#  '54243': 0.0018244305122405216,
#  '53809': 0.001822624107758001,
#  '54251': 0.001821402099966587,
#  '53803': 0.0018207811203558122,
#  '54218': 0.0018206559066099059,
#  '54215': 0.001818225296189379,
#  '53811': 0.0018169872001272877,
#  '54256': 0.0018143031789540044,
#  '54222': 0.0018107142697174512,
#  '53543': 0.0018101726122397672,
#  '53455': 0.0018079538634061673,
#  '53462': 0.0018068572677897123,
#  '53501': 0.0018042482671678005,
#  '53475': 0.0017935190757503699,
#  '53417': 0.001793283104504388,
#  '53579': 0.0017855536201334243,
#  '54190': 0.001784402825244029,
#  '53798': 0.0017806986161533463,
#  '54173': 0.0017797668665655382,
#  '53640': 0.0017736386927828642,
#  '54129': 0.0017735658837417674,
#  '53611': 0.0017730266197439155,
#  '53801': 0.0017720124782003401,
#  '53794': 0.0017718565089566262,
#  '54223': 0.0017697141139920004,
#  '54564': 0.0017691689352013155,
#  '54219': 0.0017687355417913087,
#  '53807': 0.0017648658231679615,
#  '53633': 0.0017632032491414786,
#  '53638': 0.0017608772218130524,
#  '53476': 0.001757585875573206,
#  '53784': 0.0017553345647661302,
#  '53625': 0.0017552988695922255,
#  '53486': 0.0017503532783654534,
#  '53614': 0.0017493285207551492,
#  '53446': 0.0017426578771889073,
#  '53492': 0.0017406029164667204,
#  '54176': 0.001736166605569675,
#  '53658': 0.001735439258625075,
#  '53448': 0.001734006434955061,
#  '53427': 0.001733730623258597,
#  '54188': 0.001731184082693769,
#  '54257': 0.0017300972282271925,
#  '53505': 0.0017291042645597035,
#  '53782': 0.0017226937080757493,
#  '54174': 0.001718777788750903,
#  '53667': 0.0017175565519715848,
#  '54235': 0.0017130136495241504,
#  '53639': 0.0017127758972006824,
#  '53637': 0.0017112659905795732,
#  '54241': 0.00170237278136892,
#  '53536': 0.001698554203409995,
#  '53805': 0.0016926488331183143,
#  '54253': 0.0016922378614520717,
#  '53795': 0.0016882882464265012,
#  '53599': 0.0016880376113537657,
#  '54262': 0.0016839374496928426,
#  '53603': 0.0016759788758373172,
#  '53570': 0.0016726018418278229,
#  '54172': 0.0016709079588067162,
#  '54139': 0.0016691340432235145,
#  '53456': 0.0016677348185727297,
#  '53676': 0.0016648290638794003,
#  '53546': 0.0016643848097558929,
#  '53793': 0.001662877303223019,
#  '53551': 0.001662452483458814,
#  '53463': 0.001660175178934857,
#  '53550': 0.001658854125731702,
#  '53415': 0.0016334051599585539,
#  '53554': 0.0016322284029165197,
#  '53628': 0.0016255753430355901,
#  '53553': 0.0016177762796681344,
#  '54195': 0.0016087881069411546,
#  '53792': 0.0015922330639613295,
#  '54186': 0.001589436717421428,
#  '54136': 0.0015846985108644205,
#  '54236': 0.0015805926270155855,
#  '53564': 0.00156823076006451,
#  '53489': 0.0015677364200422604,
#  '53620': 0.0015487750509524047,
#  '53497': 0.001529629424915245,
#  '53464': 0.001529161057404844,
#  '53592': 0.0015184067717751608,
#  '53650': 0.0015066037737474917,
#  '54184': 0.0015038918359586047,
#  '54226': 0.0015030546717556437,
#  '54171': 0.0014927505102176847,
#  '53622': 0.0014906263146133851,
#  '54242': 0.0014887725704129102,
#  '53499': 0.0014801601287828755,
#  '53812': 0.0014703937294211584,
#  '54164': 0.0014653481861619472,
#  '53645': 0.0014567677422734331,
#  '53506': 0.0014315111267737511,
#  '54240': 0.0014103669921683765,
#  '53457': 0.0013947465380419037,
#  '54125': 0.0013715102984341143,
#  '54185': 0.0013669689495084568,
#  '54258': 0.001340394501949053,
#  '54197': 0.001339694668767358,
#  '54216': 0.0013304576485391665,
#  '54234': 0.001330311641780511,
#  '54255': 0.0013262809541261741,
#  '53547': 0.001314622331661253,
#  '53557': 0.0013013738560884215,
#  '53641': 0.0012803598838266486,
#  '54143': 0.0012792532230305697,
#  '54131': 0.001263017988045933,
#  '53632': 0.0012493837514951582,
#  '53781': 0.0011678831374425539,
#  '54249': 0.0011406865640966682,
#  '54163': 0.0011369656766294827,
#  '53806': 0.0009302300084061421}

# %%
weights = getWeightedEdges(1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))

# %%
G = nx.Graph()
G.add_nodes_from(list(data.keys()))
G.add_weighted_edges_from(weights)
pr = nx.pagerank(G, alpha=0.85)
dict(sorted(pr.items(), key=lambda item: item[1],reverse=True))
# Out:
# {'53398': 0.013626424760508215,
#  '53280': 0.013098410606109128,
#  '53332': 0.0123423032080349,
#  '53261': 0.012302099738228073,
#  '53320': 0.012131744230562446,
#  '53328': 0.012013263530877784,
#  '53340': 0.01183944486796705,
#  '53404': 0.011023104133878763,
#  '53322': 0.011016322158570875,
#  '53396': 0.010951325882721909,
#  '53397': 0.01086018821118871,
#  '53343': 0.010554052058050318,
#  '53293': 0.010143267180174921,
#  '53257': 0.01011855092927956,
#  '53342': 0.010046633198056903,
#  '53346': 0.009604576407198582,
#  '53265': 0.009458231335364076,
#  '53324': 0.009377018872518872,
#  '53355': 0.00930669231421712,
#  '53327': 0.009207032570490381,
#  '53260': 0.009152131756504598,
#  '53408': 0.008804891430140653,
#  '53406': 0.008707652927961612,
#  '53409': 0.008647432408378359,
#  '53350': 0.008555400895496446,
#  '53319': 0.008462076972426586,
#  '53313': 0.008434045648341769,
#  '53358': 0.00833361781959852,
#  '53278': 0.008275263423891928,
#  '53325': 0.00812548542965706,
#  '53394': 0.008028119055747648,
#  '53333': 0.00801704741799999,
#  '53279': 0.00795412913289161,
#  '53349': 0.007843664241065496,
#  '53316': 0.007659095510304246,
#  '53326': 0.007585502118573869,
#  '53410': 0.007575163286801259,
#  '53393': 0.0075589589674943305,
#  '53315': 0.007557111259051698,
#  '53262': 0.007372928341893928,
#  '53405': 0.007145427639891016,
#  '53338': 0.006796817057420861,
#  '53297': 0.006793507665825061,
#  '53331': 0.006648587697103138,
#  '53339': 0.006559842583520489,
#  '53276': 0.0065078025633041586,
#  '53364': 0.006495663973385996,
#  '53294': 0.00646477524079874,
#  '53344': 0.006456016711548428,
#  '53359': 0.006353246657046724,
#  '53277': 0.006268726777017482,
#  '53302': 0.006166578602765746,
#  '53357': 0.006076756131223608,
#  '53365': 0.005805023174959686,
#  '53329': 0.005802591798241841,
#  '53402': 0.0057957088681237995,
#  '53400': 0.005707290128581297,
#  '53361': 0.005606992428612513,
#  '53353': 0.005556483632554095,
#  '53356': 0.005515679186162412,
#  '53068': 0.005510074381029025,
#  '53399': 0.00541622307513982,
#  '53321': 0.005391969689539915,
#  '53337': 0.00497053606174826,
#  '53401': 0.004946931259147124,
#  '53317': 0.004706197510102986,
#  '53363': 0.004521949251777013,
#  '53272': 0.0044187263249915445,
#  '53362': 0.00435776350407199,
#  '53424': 0.003820080225652625,
#  '53538': 0.00368524096578495,
#  '54175': 0.003630715559844787,
#  '53403': 0.00350945354940387,
#  '53669': 0.003314495053397616,
#  '53335': 0.00314433658988977,
#  '53675': 0.003123383536881041,
#  '53586': 0.0030562266134460435,
#  '53425': 0.003039213968003838,
#  '53622': 0.003021490850770075,
#  '53540': 0.002954496139647354,
#  '53588': 0.002900152960203701,
#  '54233': 0.0028641671671809266,
#  '54224': 0.0028516923041992954,
#  '53667': 0.0027895899636695624,
#  '53429': 0.002780047079371064,
#  '53537': 0.0027679653595049643,
#  '53564': 0.002706374197220495,
#  '53594': 0.002683748804586143,
#  '53810': 0.002680764452953106,
#  '53637': 0.0026752303607817346,
#  '53639': 0.002650863773699617,
#  '53644': 0.0026221026232661647,
#  '53623': 0.0025859901479287255,
#  '53790': 0.0025724272479310645,
#  '53447': 0.0025659804134971864,
#  '53599': 0.0025517035025685885,
#  '53539': 0.0025292587982847833,
#  '53497': 0.002508159239225666,
#  '53614': 0.0025073726129037476,
#  '53583': 0.002485669952129086,
#  '53677': 0.002467372410032724,
#  '53491': 0.0024474820981003455,
#  '53499': 0.002431512865429555,
#  '53487': 0.002425824601521508,
#  '53421': 0.0023903344917185062,
#  '53430': 0.0023892361189365653,
#  '53642': 0.0023842042705763873,
#  '53664': 0.0023828908615276417,
#  '54192': 0.0023730129354702163,
#  '53469': 0.0023718533936540804,
#  '54244': 0.0023638140192453003,
#  '54248': 0.0023522573123879683,
#  '54191': 0.002349434469983266,
#  '53645': 0.00234201873757294,
#  '53431': 0.0023274055194820956,
#  '53563': 0.0023118886375691964,
#  '53671': 0.0023045520573857716,
#  '54250': 0.0022913327697216455,
#  '53555': 0.002289156051707199,
#  '53493': 0.0022716102243965403,
#  '53473': 0.002262009022079299,
#  '53609': 0.002241056994480406,
#  '53676': 0.002238430674546079,
#  '53496': 0.002216017342115319,
#  '53670': 0.002200762338439011,
#  '54194': 0.002198098892063549,
#  '53498': 0.002175468494483599,
#  '53634': 0.002168880958629212,
#  '54138': 0.0021561616995738253,
#  '53605': 0.0021466350403653704,
#  '54193': 0.0021444326543395135,
#  '53604': 0.002140878993769504,
#  '53619': 0.0021399506715524034,
#  '53638': 0.0021311426521394665,
#  '53591': 0.002122307292523695,
#  '53600': 0.002112999015494957,
#  '53446': 0.002112204280061287,
#  '54189': 0.00210655562161241,
#  '53501': 0.002103637634788226,
#  '53795': 0.00208491303095196,
#  '54142': 0.0020769832717834956,
#  '53423': 0.0020640840012783835,
#  '53502': 0.0020327767471568048,
#  '54246': 0.002024782017252001,
#  '53603': 0.0020187360466088593,
#  '54225': 0.002008169539342336,
#  '53606': 0.0020052361183810607,
#  '53472': 0.0020049962232756863,
#  '54217': 0.002002797296327983,
#  '54237': 0.0020024943430872804,
#  '53589': 0.0019982672471733297,
#  '54133': 0.0019975510160425533,
#  '54481': 0.0019973014105056385,
#  '53541': 0.001952127215078357,
#  '53635': 0.0019496107595091208,
#  '54134': 0.0019464542355739545,
#  '53482': 0.0019433101007462817,
#  '54261': 0.00194180712865154,
#  '54258': 0.0019336809855296632,
#  '54221': 0.0019311989131615803,
#  '53629': 0.0019211036395372148,
#  '53803': 0.001909176980960302,
#  '53426': 0.001905183303296932,
#  '53601': 0.0019048851987101107,
#  '53495': 0.0018941344527475153,
#  '53544': 0.001888609885829637,
#  '54126': 0.001886557626303516,
#  '53673': 0.0018800821632419702,
#  '53804': 0.001870003050418702,
#  '53557': 0.0018642479751994209,
#  '54247': 0.0018533948420366383,
#  '53505': 0.0018416461996298428,
#  '53581': 0.001834789474384127,
#  '54127': 0.001831042102659555,
#  '53579': 0.00181661573947814,
#  '54249': 0.0018141066635699262,
#  '54219': 0.0017883486511445497,
#  '54183': 0.0017852382942122795,
#  '54164': 0.001784479280448086,
#  '54245': 0.0017788910133878031,
#  '53598': 0.0017692714390586087,
#  '53570': 0.0017672862256166806,
#  '53504': 0.0017635681189212666,
#  '54260': 0.0017611895244500138,
#  '53458': 0.0017589371492962062,
#  '54163': 0.0017476508662070168,
#  '54128': 0.0017430790693963812,
#  '53631': 0.0017365388786943496,
#  '54141': 0.0017354776741905036,
#  '53488': 0.0017246414723861919,
#  '53412': 0.0017217127868554068,
#  '53792': 0.0017123236900408218,
#  '53489': 0.001710695038144854,
#  '53624': 0.0017052007522771451,
#  '53479': 0.0017048392737497198,
#  '53782': 0.0017002542069005826,
#  '54196': 0.0016997451688794364,
#  '54137': 0.0016846115131963074,
#  '54136': 0.0016840468714074608,
#  '53428': 0.0016834323499528697,
#  '54218': 0.0016698492000246628,
#  '53575': 0.001668345456330975,
#  '54135': 0.0016549886787880182,
#  '54256': 0.0016538033540218122,
#  '53811': 0.0016506398660159035,
#  '53549': 0.0016491582168456336,
#  '53809': 0.0016422241357277232,
#  '54251': 0.0016418676379825342,
#  '54238': 0.0016387867283335791,
#  '53649': 0.0016055517494442636,
#  '54144': 0.0016046339018621167,
#  '53448': 0.0016033885952136324,
#  '53602': 0.001602817912140807,
#  '53657': 0.001600954349666042,
#  '54129': 0.0015990975833733065,
#  '54468': 0.001594384219264044,
#  '53413': 0.0015756053795118684,
#  '53536': 0.0015622254255142805,
#  '54220': 0.0015485224033262234,
#  '54259': 0.0015484221065055453,
#  '53454': 0.0015464080331665385,
#  '53550': 0.0015463338991352049,
#  '54160': 0.0015442988284990115,
#  '53558': 0.0015414296519687305,
#  '53783': 0.0015283723934403936,
#  '53552': 0.0015273136594100795,
#  '53414': 0.0015242507486722663,
#  '53808': 0.001522359534523157,
#  '53457': 0.0015199390163186,
#  '53630': 0.0015188718020611581,
#  '53794': 0.0015175599203745619,
#  '54239': 0.0015115760920152246,
#  '53807': 0.0015085316415050455,
#  '53503': 0.0015071280265693031,
#  '54231': 0.0015070737069874747,
#  '53582': 0.0015055509185950933,
#  '54222': 0.001503336994033359,
#  '54176': 0.0014924086026296486,
#  '54173': 0.0014904747542915109,
#  '53663': 0.0014799419095330346,
#  '53500': 0.0014699447154404072,
#  '54190': 0.0014655765620600683,
#  '53420': 0.0014618092812579606,
#  '53627': 0.0014571263192725444,
#  '53650': 0.0014543431305355332,
#  '54171': 0.001450727368584671,
#  '53492': 0.001444635308838746,
#  '54564': 0.0014430102401776957,
#  '53633': 0.0014399285663416845,
#  '54235': 0.001434087125837539,
#  '53476': 0.0014298557627318213,
#  '54174': 0.0014272503842623577,
#  '53592': 0.0014243390812091175,
#  '53474': 0.0014235950768963386,
#  '53417': 0.0014163771112764053,
#  '53611': 0.0014145675101111985,
#  '54254': 0.0014137695223253332,
#  '54242': 0.0014123825841874502,
#  '54187': 0.0014003460034818151,
#  '53415': 0.001398076628448847,
#  '54253': 0.0013976779241973252,
#  '53462': 0.001389348907491762,
#  '54257': 0.0013756615133089455,
#  '54184': 0.0013684378734758545,
#  '53620': 0.0013617255518295981,
#  '53475': 0.0013359225773135282,
#  '53801': 0.0013321905733968049,
#  '53456': 0.0013285680949309618,
#  '54186': 0.0013230743791726816,
#  '54262': 0.0013093562214920732,
#  '53786': 0.0013083376239535903,
#  '53486': 0.0013032777328762873,
#  '54226': 0.0013006638749739198,
#  '54139': 0.0012938685529841336,
#  '53791': 0.0012935116469393942,
#  '53805': 0.0012934244088467636,
#  '53784': 0.0012910240864883057,
#  '53455': 0.0012877755453287972,
#  '54170': 0.0012760693208349846,
#  '54172': 0.0012696185444702618,
#  '53812': 0.0012676430106037552,
#  '54223': 0.001265323023186586,
#  '53798': 0.0012638096395834737,
#  '53553': 0.0012481297691555903,
#  '53411': 0.0012436686238983434,
#  '53640': 0.0012421074720038391,
#  '53416': 0.0012211906466764934,
#  '53554': 0.0012152559118338321,
#  '54243': 0.0012130000788614335,
#  '54216': 0.0011864785488013502,
#  '54241': 0.0011668011463107782,
#  '54215': 0.0011406631069937636,
#  '53427': 0.001125707300159874,
#  '53793': 0.0011094249020923914,
#  '53628': 0.001104982443988357,
#  '53463': 0.0011018609473644745,
#  '53551': 0.001099631193596853,
#  '54125': 0.0010967101099610406,
#  '53543': 0.0010947623280880422,
#  '53506': 0.0010928726263176073,
#  '54188': 0.001088016419484081,
#  '53632': 0.0010849255171363425,
#  '53625': 0.0010353258258006435,
#  '53658': 0.001026909496333919,
#  '54185': 0.0010245594965022948,
#  '53546': 0.0009791249976715778,
#  '54240': 0.0009774770833211204,
#  '54236': 0.0009414437925390421,
#  '53464': 0.000936115676745069,
#  '54197': 0.0008961994285365865,
#  '54195': 0.0008897784780045757,
#  '53641': 0.000835376506235281,
#  '53781': 0.000808635204130635,
#  '54255': 0.0007964512160243574,
#  '54131': 0.0007540789931213508,
#  '54234': 0.000748732381853767,
#  '53547': 0.000705884505215001,
#  '54143': 0.0006781669432485793,
#  '53806': 0.0006312367360168576}
